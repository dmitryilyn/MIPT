# %%
import os
import sqlite3
import pandas as pd
import re
import numpy as np
from collections import Counter

# %% [markdown]
# ### Объявляем вспомогательные функции для соединения с базой

# %%
def create_connection(path):
    connection = None
    try:
        if os.path.exists(path):
            os.remove(path)
        connection = sqlite3.connect(path)
        print("Connection to SQLite DB successful")
    except sqlite3.Error as e:
        print(f"The error '{e}' occurred")

    return connection

# %%
def execute_query(connection, query):
    cursor = connection.cursor()
    try:
        cursor.execute(query)
        connection.commit()
        print("Query executed successfully")
    except Error as e:
        print(f"The error '{e}' occurred")

# %% [markdown]
# ## Шаг 1

# %% [markdown]
# ### Загружаем csv-файлы в дата-фреймы и очищаем их

# %%
def remove_non_latin_symbols(text):
    return re.sub(r"[^a-zA-Z\s]", "", text)

# %%
stopwords_df = pd.read_csv("stopwords.csv", header=None, names=['word'])
stopwords_df["word"] = stopwords_df["word"].str.lower().apply(remove_non_latin_symbols)

# %%
stopwords = set(stopwords_df['word'].values)

def remove_stopwords(text):
    words = text.split()
    filtered_words = [word for word in words if word.lower() not in stopwords]
    return ' '.join(filtered_words)

# %%
articles_df = pd.read_csv("articles.csv", sep=";", header=None, names=['id', 'text'])
articles_df["text"] = articles_df["text"].str.lower().apply(remove_non_latin_symbols).apply(remove_stopwords)

# %% [markdown]
# ### Устанавливаем соединение с базой, создаем таблицы, и загружаем в них очищенные датафреймы

# %%
connection = create_connection("articles.db")
# Out:
# Connection to SQLite DB successful

# %%
create_articles_table = """
    CREATE TABLE IF NOT EXISTS articles (
        id INTEGER,
        text TEXT
    );
"""

# %%
execute_query(connection, create_articles_table)
# Out:
# Query executed successfully

# %%
articles_df.to_sql("articles", connection, if_exists="append", index=False)
pd.read_sql(f"SELECT * FROM articles", connection)
# Out:
#       id                                               text
# 0      1  bradley charles cooper born january american a...
# 1      2  cooper enrolled mfa program actors studio begi...
# 2      3  cooper found greater success romantic comedy s...
# 3      4  labeled sex symbol media cooper named people m...
# 4      5  cooper born january abington township near phi...
# ..   ...                                                ...
# 355  356  roosevelt won reelection lower percentage elec...
# 356  357  last election new hampshire oregon voted democ...
# 357  358     elections eventual winner carry ohio elections
# 358  359  electoral votes received roosevelt added elect...
# 359  360  source popular vote leip david presidential el...
#
# [360 rows x 2 columns]

# %%
create_stopwords_table = """
    CREATE TABLE IF NOT EXISTS stopwords (
        word TEXT
    );
"""

# %%
execute_query(connection, create_stopwords_table)
# Out:
# Query executed successfully

# %%
stopwords_df.to_sql("stopwords", connection, if_exists="append", index=False)
pd.read_sql(f"SELECT * FROM stopwords", connection)
# Out:
#           word
# 0            x
# 1            y
# 2         your
# 3        yours
# 4     yourself
# ..         ...
# 728    excepts
# 729     except
# 730  excepting
# 731       exes
# 732     enough
#
# [733 rows x 1 columns]

# %% [markdown]
# ## Шаг 2

# %% [markdown]
# Для каждой комбинации слов посчитать NPMI и вывести на экран TOP-50 самых популярных коллокаций, отсортированных по убыванию значения NPMI.\
# Комбинацию слов объединить пробелом.

# %% [markdown]
# ### Вариант №1: используя Pandas

# %%
# Создадим list с биграммами
bigrams = []
for text in articles_df["text"].tolist():
    words = text.split()
    bigrams.extend([(words[i], words[i+1]) for i in range(len(words)-1)])

# Создаем Counter'ы для списка слов и списка биграмм
word_counts = Counter(sum([text.split() for text in articles_df["text"].tolist()], [])) #Примечание: sum(list, []) - это просто превращение списка списков в "плоский" список
bigram_counts = Counter(bigrams)

# Расчитываем NPMI
npmi_scores = {}
for bigram in bigram_counts:
    w1, w2 = bigram
    p_w1w2 = bigram_counts[bigram]/sum(bigram_counts.values())
    p_w1 = word_counts[w1]/sum(word_counts.values())
    p_w2 = word_counts[w2]/sum(word_counts.values())
    npmi = np.log(p_w1w2 / (p_w1 * p_w2)) / -np.log(p_w1w2)
    npmi_scores[bigram] = npmi

# Сохраняем NPMI scores и bigrams в pandas dataframe
npmi_df = pd.DataFrame(list(npmi_scores.items()), columns=["bigram", "npmi_score"])
npmi_df["bigram"] = [' '.join(bigram) for bigram in npmi_df["bigram"]]

# Выводим сортированный по NPMI топ-50
npmi_df = npmi_df.sort_values(by=['npmi_score'], ascending=False)
npmi_df.head(50)
# Out:
#                                    bigram  npmi_score
# 4211                             fish fry    1.005224
# 191                       nightmare alley    1.005107
# 118                      linings playbook    1.005107
# 533                           los angeles    1.005107
# 1448                     guardians galaxy    1.004971
# 5528                         willy wanker    1.004805
# 11710                   iberian peninsula    1.004805
# 2015                       licorice pizza    1.004805
# 2328                         barack obama    1.004805
# 3804                      ella fitzgerald    1.004590
# 1454                    severely deformed    1.004590
# 1489                       clint eastwood    1.004590
# 7737                           angkor wat    1.004590
# 12900                      milvian bridge    1.004590
# 6919                individuals hazardous    1.004590
# 9250                    apostolicae sedis    1.004590
# 4019                       foot minstrels    1.004590
# 1212                     bipolar disorder    1.004590
# 8464                        carries heavy    1.004590
# 4018                          rabbit foot    1.004590
# 3360                          steven moll    1.004590
# 6920                  hazardous equipment    1.004590
# 3356                        allison rader    1.004590
# 2942                         parke custis    1.004590
# 5246                     elderly neighbor    1.004590
# 2964                         amos bronson    1.004590
# 5652                            pulls gun    1.004590
# 14783                      harold stassen    1.004590
# 3957                       joel whitburns    1.004590
# 6989                     herbal medicines    1.004590
# 6918                unskilled individuals    1.004590
# 3802                          bing crosby    1.004590
# 6921                 equipment unsanitary    1.004590
# 816                          phil wenneck    1.004590
# 217                           irina shayk    1.004590
# 4468                        here chickens    1.004590
# 1514                            pounds kg    1.004590
# 4085                      elks rendezvous    1.004590
# 12368                    parthenon frieze    1.004264
# 3932                          milt gabler    1.004264
# 1458              coveney whatsonstagecom    1.004264
# 5617                     teenager resists    1.004264
# 1462                          avoids trap    1.004264
# 13794                      ambitus templi    1.004264
# 9718                    fears prosecution    1.004264
# 11510                    furets massively    1.004264
# 11513                  essay interpreting    1.004264
# 5434   antiestablishment environmentalist    1.004264
# 5437                           dirty eats    1.004264
# 5438                         eats garbage    1.004264

# %% [markdown]
# ### Вариант №2: используя SQL

# %%
top_50_by_npmi_query = f"""
    WITH RECURSIVE split_words(id, word, pos, text) AS (
        SELECT 
            id,
            substr(text || ' ', 1, instr(text || ' ', ' ')),
            instr(text || ' ', ' '),
            text
        FROM 
            articles
        UNION ALL
        SELECT 
            id,
            substr(text || ' ', pos, instr(substr(text || ' ', pos) || ' ', ' ')),
            instr(substr(text || ' ', pos) || ' ', ' ') + pos,
            text
        FROM 
            split_words
        WHERE 
            pos < length(text || ' ')
    ),
    bigrams AS (
        SELECT 
            id, 
            word || ' ' || lead(word) OVER (PARTITION BY id ORDER BY pos) AS bigram
        FROM 
            split_words
        WHERE 
            TRIM(word) != ''
    )
    SELECT
        bigram,
        w1w2_count,
        total_bigrams_count,
        w1_count,
        w2_count,
        total_words_count,
        p_w1w2,
        p_w1,
        p_w2,
        CAST(log(p_w1w2 / (p_w1 * p_w2)) / -log(p_w1w2) AS REAL) AS npmi
    FROM
        (
            SELECT
                *,
                CAST(w1w2_count AS REAL)/CAST(total_bigrams_count AS REAL) AS p_w1w2,
                CAST(w1_count AS REAL)/CAST(total_words_count AS REAL) AS p_w1,
                CAST(w2_count AS REAL)/CAST(total_words_count AS REAL) AS p_w2
            FROM
            (
                SELECT
                    bigram,
                    count(*) AS w1w2_count,
                    (SELECT count(*) FROM bigrams WHERE bigram IS NOT NULL) AS total_bigrams_count,
                    (SELECT count(*) FROM split_words WHERE b.bigram LIKE word || ' %') AS w1_count,
                    (SELECT count(*) FROM split_words WHERE b.bigram LIKE '% ' || word) AS w2_count,
                    (SELECT count(*) FROM split_words WHERE TRIM(word) != '') AS total_words_count
                FROM 
                    bigrams b
                WHERE 
                    b.bigram IS NOT NULL
                GROUP BY 
                    b.bigram
            )
        )
    ORDER BY 
        10 DESC
    LIMIT 50
    ;
"""

# %%
pd.read_sql(top_50_by_npmi_query, connection)
# Out:
#                          bigram  w1w2_count  total_bigrams_count  w1_count  \
# 0                    fish  fry            6                17141         6
# 1            linings  playbook            5                17141         5
# 2                 los  angeles            5                17141         5
# 3             nightmare  alley            5                17141         5
# 4            guardians  galaxy            4                17141         4
# 5                barack  obama            3                17141         3
# 6           iberian  peninsula            3                17141         3
# 7              licorice  pizza            3                17141         3
# 8                willy  wanker            3                17141         3
# 9               allison  rader            2                17141         2
# 10               amos  bronson            2                17141         2
# 11                 angkor  wat            2                17141         2
# 12          apostolicae  sedis            2                17141         2
# 13                bing  crosby            2                17141         2
# 14           bipolar  disorder            2                17141         2
# 15              carries  heavy            2                17141         2
# 16             clint  eastwood            2                17141         2
# 17           elderly  neighbor            2                17141         2
# 18            elks  rendezvous            2                17141         2
# 19            ella  fitzgerald            2                17141         2
# 20       equipment  unsanitary            2                17141         2
# 21             foot  minstrels            2                17141         2
# 22             harold  stassen            2                17141         2
# 23        hazardous  equipment            2                17141         2
# 24           herbal  medicines            2                17141         2
# 25              here  chickens            2                17141         2
# 26      individuals  hazardous            2                17141         2
# 27                irina  shayk            2                17141         2
# 28             joel  whitburns            2                17141         2
# 29             milvian  bridge            2                17141         2
# 30               parke  custis            2                17141         2
# 31               phil  wenneck            2                17141         2
# 32                  pounds  kg            2                17141         2
# 33                  pulls  gun            2                17141         2
# 34                rabbit  foot            2                17141         2
# 35          severely  deformed            2                17141         2
# 36                steven  moll            2                17141         2
# 37      unskilled  individuals            2                17141         2
# 38                 ab  omnibus            1                17141         1
# 39          abington  township            1                17141         1
# 40          abnormal  bleeding            1                17141         1
# 41  abortionistmidwife  madame            1                17141         1
# 42            abraham  lincoln            1                17141         1
# 43             abruzzo  naples            1                17141         1
# 44               abscam  sting            1                17141         1
# 45            absurd  menacing            1                17141         1
# 46      accelerate  completion            1                17141         1
# 47      accompanying  imperial            1                17141         1
# 48            achilles  tendon            1                17141         1
# 49               acid  attacks            1                17141         1
#
#     w2_count  total_words_count    p_w1w2      p_w1      p_w2      npmi
# 0          6              17501  0.000350  0.000343  0.000343  1.005224
# 1          5              17501  0.000292  0.000286  0.000286  1.005107
# 2          5              17501  0.000292  0.000286  0.000286  1.005107
# 3          5              17501  0.000292  0.000286  0.000286  1.005107
# 4          4              17501  0.000233  0.000229  0.000229  1.004971
# 5          3              17501  0.000175  0.000171  0.000171  1.004805
# 6          3              17501  0.000175  0.000171  0.000171  1.004805
# 7          3              17501  0.000175  0.000171  0.000171  1.004805
# 8          3              17501  0.000175  0.000171  0.000171  1.004805
# 9          2              17501  0.000117  0.000114  0.000114  1.004590
# 10         2              17501  0.000117  0.000114  0.000114  1.004590
# 11         2              17501  0.000117  0.000114  0.000114  1.004590
# 12         2              17501  0.000117  0.000114  0.000114  1.004590
# 13         2              17501  0.000117  0.000114  0.000114  1.004590
# 14         2              17501  0.000117  0.000114  0.000114  1.004590
# 15         2              17501  0.000117  0.000114  0.000114  1.004590
# 16         2              17501  0.000117  0.000114  0.000114  1.004590
# 17         2              17501  0.000117  0.000114  0.000114  1.004590
# 18         2              17501  0.000117  0.000114  0.000114  1.004590
# 19         2              17501  0.000117  0.000114  0.000114  1.004590
# 20         2              17501  0.000117  0.000114  0.000114  1.004590
# 21         2              17501  0.000117  0.000114  0.000114  1.004590
# 22         2              17501  0.000117  0.000114  0.000114  1.004590
# 23         2              17501  0.000117  0.000114  0.000114  1.004590
# 24         2              17501  0.000117  0.000114  0.000114  1.004590
# 25         2              17501  0.000117  0.000114  0.000114  1.004590
# 26         2              17501  0.000117  0.000114  0.000114  1.004590
# 27         2              17501  0.000117  0.000114  0.000114  1.004590
# 28         2              17501  0.000117  0.000114  0.000114  1.004590
# 29         2              17501  0.000117  0.000114  0.000114  1.004590
# 30         2              17501  0.000117  0.000114  0.000114  1.004590
# 31         2              17501  0.000117  0.000114  0.000114  1.004590
# 32         2              17501  0.000117  0.000114  0.000114  1.004590
# 33         2              17501  0.000117  0.000114  0.000114  1.004590
# 34         2              17501  0.000117  0.000114  0.000114  1.004590
# 35         2              17501  0.000117  0.000114  0.000114  1.004590
# 36         2              17501  0.000117  0.000114  0.000114  1.004590
# 37         2              17501  0.000117  0.000114  0.000114  1.004590
# 38         1              17501  0.000058  0.000057  0.000057  1.004264
# 39         1              17501  0.000058  0.000057  0.000057  1.004264
# 40         1              17501  0.000058  0.000057  0.000057  1.004264
# 41         1              17501  0.000058  0.000057  0.000057  1.004264
# 42         1              17501  0.000058  0.000057  0.000057  1.004264
# 43         1              17501  0.000058  0.000057  0.000057  1.004264
# 44         1              17501  0.000058  0.000057  0.000057  1.004264
# 45         1              17501  0.000058  0.000057  0.000057  1.004264
# 46         1              17501  0.000058  0.000057  0.000057  1.004264
# 47         1              17501  0.000058  0.000057  0.000057  1.004264
# 48         1              17501  0.000058  0.000057  0.000057  1.004264
# 49         1              17501  0.000058  0.000057  0.000057  1.004264

# %% [markdown]
# ### Закрываем соединение

# %%
connection.close()
